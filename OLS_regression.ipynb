# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

import statsmodels.api as sm

# %% [markdown]
# ## Load and normalize data

# %%
labels_csv = "./data/csv/keeper_survey_avg.csv"
labels_df = pd.read_csv(labels_csv).drop(['treatment', 'conversation'], axis=1)
labels_df
# Out:
#         ease        sp   anxiety      tone
# 0   3.500000  1.642857  2.500000  2.781250
# 1   3.166667  1.535714  2.000000  1.937500
# 2   4.000000  2.571429  2.500000  2.729167
# 3   2.666667  1.571429  2.416667  2.125000
# 4   3.000000  1.964286  2.125000  2.156250
# 5   2.777778  1.714286  1.833333  2.104167
# 6   2.777778  1.428571  1.666667  2.083333
# 7   2.000000  2.000000  1.800000  1.812500
# 8   1.833333  1.535714  1.500000  1.578125
# 9   3.166667  1.428571  2.000000  1.875000
# 10  3.222222  1.238095  2.833333  2.250000
# 11  2.416667  1.750000  2.687500  2.421875
# 12  2.111111  2.285714  1.833333  2.229167
# 13  3.222222  2.142857  2.375000  2.739583
# 14  3.722222  2.000000  2.416667  2.552083
# 15  3.500000  1.857143  2.250000  2.000000
# 16  2.833333  2.392857  2.375000  2.312500
# 17  2.833333  1.642857  1.625000  2.109375
# 18  1.866667  1.828571  1.800000  2.300000
# 19  2.611111  1.761905  1.583333  1.843750
# 20  2.666667  2.285714  1.833333  2.166667

# %%
labels_scaler = StandardScaler()
labels_scaled = labels_scaler.fit_transform(labels_df)
labels_scaled
# Out:
# array([[ 1.12053573, -0.56717128,  1.07123636,  1.88564877],
#        [ 0.5440249 , -0.88005912, -0.24495848, -0.83095033],
#        [ 1.98530198,  2.14452329,  1.07123636,  1.71795747],
#        [-0.32074134, -0.77576317,  0.85187055, -0.22726164],
#        [ 0.25576949,  0.37149222,  0.08409023, -0.12664686],
#        [-0.12857107, -0.35857939, -0.6836901 , -0.29433816],
#        [-0.12857107, -1.19294695, -1.12242171, -0.36141469],
#        [-1.47376301,  0.47578817, -0.77143642, -1.23340946],
#        [-1.76201842, -0.88005912, -1.56115333, -1.98802032],
#        [ 0.5440249 , -1.19294695, -0.24495848, -1.0321799 ],
#        [ 0.64011004, -1.749192  ,  1.94869959,  0.17519748],
#        [-0.75312447, -0.25428345,  1.56480943,  0.72857878],
#        [-1.28159273,  1.31015573, -0.6836901 ,  0.10812096],
#        [ 0.64011004,  0.89297195,  0.74218765,  1.75149573],
#        [ 1.50487629,  0.47578817,  0.85187055,  1.14780704],
#        [ 1.12053573,  0.05860439,  0.41313894, -0.62972077],
#        [-0.03248593,  1.62304357,  0.74218765,  0.37642705],
#        [-0.03248593, -0.56717128, -1.23210462, -0.27756903],
#        [-1.70436734, -0.02483237, -0.77143642,  0.33618114],
#        [-0.41682648, -0.21951813, -1.34178752, -1.13279468],
#        [-0.32074134,  1.31015573, -0.6836901 , -0.0931086 ]])

# %%
drop_feats=["Conversation ID", "Mean inter-speaker silence", "Interruption rate"]

data_full_csv = "./data/csv/keeper_metrics_full.csv"
data_part2_csv = "./data/csv/keeper_metrics_part2.csv"
data_full_df = pd.read_csv(data_full_csv, delimiter='\t').drop(drop_feats, axis=1)
data_part2_df = pd.read_csv(data_part2_csv, delimiter='\t').drop(drop_feats, axis=1)

# %%
data_full_df
# Out:
#     Words per hour  Speech per turn  Turn taking balance  Grade level  \
# 0          6373.99             9.02                0.966         2.61
# 1          6493.69             9.42                0.959         3.08
# 2          5119.84             8.54                0.938         2.55
# 3          7828.87             5.62                0.983         0.96
# 4          6318.28             8.19                0.956         1.41
# 5          7501.94             7.71                0.975         1.97
# 6         10473.77             7.62                0.877         3.81
# 7         11367.38             6.00                0.873         3.03
# 8          9562.37             9.58                0.857         3.61
# 9          6191.68             6.60                0.990         1.58
# 10         5917.47            18.84                0.998         3.34
# 11        11318.63             6.76                0.886         4.14
# 12         5270.34            15.97                0.968         3.43
# 13         6367.84             9.14                0.977         2.57
# 14        11726.67            11.07                0.844         5.12
# 15        12352.32             8.81                0.865         3.19
# 16        11006.51            10.25                0.871         4.76
# 17        11580.60            13.16                0.861         4.90
# 18        10824.36             9.23                0.905         3.94
# 19        11062.42             7.37                0.871         2.90
# 20        10790.56            14.07                0.900         4.92
#
#     MATTR lexical diversity  Mean word length  VADER sentiment  \
# 0                       444              4.28            0.299
# 1                       406              4.33            0.294
# 2                       374              4.30            0.262
# 3                       446              4.22            0.185
# 4                       407              4.23            0.233
# 5                       425              4.25            0.265
# 6                       440              4.28            0.274
# 7                       439              4.22            0.204
# 8                       418              4.21            0.247
# 9                       416              4.31            0.272
# 10                      399              4.26            0.282
# 11                      411              4.31            0.272
# 12                      394              4.29            0.246
# 13                      418              4.28            0.243
# 14                      414              4.26            0.279
# 15                      411              4.19            0.396
# 16                      403              4.25            0.330
# 17                      420              4.24            0.356
# 18                      397              4.14            0.237
# 19                      407              4.11            0.262
# 20                      395              4.20            0.262
#
#     Responsivity rate
# 0               0.152
# 1               0.197
# 2               0.132
# 3               0.137
# 4               0.211
# 5               0.226
# 6               0.081
# 7               0.089
# 8               0.082
# 9               0.086
# 10              0.317
# 11              0.126
# 12              0.245
# 13              0.133
# 14              0.117
# 15              0.132
# 16              0.155
# 17              0.179
# 18              0.107
# 19              0.075
# 20              0.125

# %%
data_full_scaler = StandardScaler()
data_full_scaled = data_full_scaler.fit_transform(data_full_df)
data_full_scaled.shape
# Out:
# (21, 8)

# %%
data_part2_scaler = StandardScaler()
data_part2_scaled = data_part2_scaler.fit_transform(data_part2_df)
data_part2_scaled.shape
# Out:
# (21, 8)

# %% [markdown]
# ## OLS for full Keeper conversations

# %%
ease_np = labels_df['ease'].to_numpy().reshape(-1, 1)
sp_np = labels_df['sp'].to_numpy().reshape(-1, 1)
anxiety_np = labels_df['anxiety'].to_numpy().reshape(-1, 1)
tone_np = labels_df['tone'].to_numpy().reshape(-1, 1)

# %%
# ease
X2 = sm.add_constant(data_full_scaled)
est = sm.OLS(ease_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     1.334
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.315
# Time:                        18:38:20   Log-Likelihood:                -11.614
# No. Observations:                  21   AIC:                             41.23
# Df Residuals:                      12   BIC:                             50.63
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8521      0.121     23.486      0.000       2.588       3.117
# x1            -0.1337      0.438     -0.305      0.765      -1.088       0.821
# x2             0.0325      0.349      0.093      0.927      -0.728       0.793
# x3             0.0094      0.340      0.028      0.978      -0.732       0.751
# x4            -0.1753      0.433     -0.404      0.693      -1.120       0.769
# x5            -0.0714      0.163     -0.439      0.669      -0.426       0.283
# x6             0.1518      0.234      0.649      0.529      -0.358       0.661
# x7             0.3559      0.153      2.324      0.038       0.022       0.690
# x8            -0.1250      0.237     -0.527      0.608      -0.642       0.392
# ==============================================================================
# Omnibus:                        3.697   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                1.796
# Skew:                           0.511   Prob(JB):                        0.407
# Kurtosis:                       4.005   Cond. No.                         9.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# social presence
X2 = sm.add_constant(data_full_scaled)
est = sm.OLS(sp_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.9855
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.491
# Time:                        18:39:14   Log-Likelihood:                -1.9897
# No. Observations:                  21   AIC:                             21.98
# Df Residuals:                      12   BIC:                             31.38
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8371      0.077     23.923      0.000       1.670       2.004
# x1            -0.1797      0.277     -0.649      0.529      -0.783       0.424
# x2            -0.1762      0.221     -0.799      0.440      -0.657       0.304
# x3            -0.1036      0.215     -0.482      0.639      -0.573       0.365
# x4             0.1783      0.274      0.650      0.528      -0.419       0.775
# x5            -0.1770      0.103     -1.719      0.111      -0.401       0.047
# x6            -0.0394      0.148     -0.266      0.795      -0.362       0.283
# x7            -0.0553      0.097     -0.571      0.579      -0.266       0.156
# x8             0.0445      0.150      0.297      0.772      -0.282       0.372
# ==============================================================================
# Omnibus:                        5.866   Durbin-Watson:                   1.710
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                1.750
# Skew:                          -0.168   Prob(JB):                        0.417
# Kurtosis:                       1.626   Cond. No.                         9.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# anxiety
X2 = sm.add_constant(data_full_scaled)
est = sm.OLS(anxiety_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                 -0.113
# Method:                 Least Squares   F-statistic:                    0.7462
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.653
# Time:                        18:39:39   Log-Likelihood:                -5.2324
# No. Observations:                  21   AIC:                             28.46
# Df Residuals:                      12   BIC:                             37.87
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0931      0.090     23.356      0.000       1.898       2.288
# x1             0.2861      0.323      0.885      0.394      -0.418       0.990
# x2            -0.0156      0.257     -0.061      0.953      -0.577       0.545
# x3             0.2358      0.251      0.939      0.366      -0.311       0.783
# x4            -0.0611      0.320     -0.191      0.852      -0.758       0.636
# x5            -0.0978      0.120     -0.814      0.431      -0.360       0.164
# x6             0.1902      0.173      1.102      0.292      -0.186       0.566
# x7             0.0141      0.113      0.125      0.903      -0.232       0.260
# x8             0.0717      0.175      0.410      0.689      -0.310       0.453
# ==============================================================================
# Omnibus:                        5.752   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                1.656
# Skew:                          -0.012   Prob(JB):                        0.437
# Kurtosis:                       1.625   Cond. No.                         9.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# anxiety
X2 = sm.add_constant(data_full_scaled)
est = sm.OLS(tone_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                 -0.052
# Method:                 Least Squares   F-statistic:                    0.8768
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.561
# Time:                        18:40:35   Log-Likelihood:               -0.41000
# No. Observations:                  21   AIC:                             18.82
# Df Residuals:                      12   BIC:                             28.22
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1956      0.071     30.825      0.000       2.040       2.351
# x1            -0.2845      0.257     -1.107      0.290      -0.844       0.275
# x2            -0.2907      0.205     -1.421      0.181      -0.737       0.155
# x3             0.2170      0.200      1.087      0.298      -0.218       0.652
# x4             0.4796      0.254      1.887      0.084      -0.074       1.033
# x5             0.0143      0.095      0.150      0.883      -0.194       0.222
# x6            -0.0885      0.137     -0.645      0.531      -0.387       0.210
# x7             0.0495      0.090      0.551      0.592      -0.146       0.245
# x8             0.0545      0.139      0.392      0.702      -0.249       0.358
# ==============================================================================
# Omnibus:                        0.818   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.523
# Skew:                          -0.373   Prob(JB):                        0.770
# Kurtosis:                       2.797   Cond. No.                         9.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## OLS for part 2 of Keeper conversations

# %%
# ease
X2 = sm.add_constant(data_part2_scaled)
est = sm.OLS(ease_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                 -0.043
# Method:                 Least Squares   F-statistic:                    0.8967
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.548
# Time:                        18:41:32   Log-Likelihood:                -13.372
# No. Observations:                  21   AIC:                             44.74
# Df Residuals:                      12   BIC:                             54.14
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8521      0.132     21.600      0.000       2.564       3.140
# x1            -0.2242      0.312     -0.718      0.486      -0.904       0.456
# x2            -0.1007      0.259     -0.388      0.705      -0.666       0.465
# x3             0.1262      0.351      0.360      0.725      -0.639       0.891
# x4             0.1214      0.397      0.306      0.765      -0.744       0.987
# x5             0.0698      0.205      0.341      0.739      -0.377       0.516
# x6            -0.0194      0.214     -0.091      0.929      -0.485       0.446
# x7             0.3734      0.302      1.237      0.240      -0.284       1.031
# x8            -0.2512      0.302     -0.832      0.422      -0.909       0.407
# ==============================================================================
# Omnibus:                        3.952   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.139   Jarque-Bera (JB):                2.121
# Skew:                           0.714   Prob(JB):                        0.346
# Kurtosis:                       3.619   Cond. No.                         8.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# social presence
X2 = sm.add_constant(data_part2_scaled)
est = sm.OLS(sp_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                 -0.192
# Method:                 Least Squares   F-statistic:                    0.5979
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.763
# Time:                        18:41:38   Log-Likelihood:                -3.7701
# No. Observations:                  21   AIC:                             25.54
# Df Residuals:                      12   BIC:                             34.94
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8371      0.084     21.978      0.000       1.655       2.019
# x1            -0.0750      0.198     -0.380      0.711      -0.506       0.356
# x2            -0.0838      0.164     -0.510      0.619      -0.442       0.274
# x3             0.0110      0.222      0.050      0.961      -0.473       0.495
# x4             0.0817      0.251      0.325      0.751      -0.466       0.630
# x5            -0.2190      0.130     -1.689      0.117      -0.502       0.064
# x6             0.0304      0.135      0.225      0.826      -0.264       0.325
# x7            -0.1505      0.191     -0.788      0.446      -0.567       0.266
# x8            -0.0191      0.191     -0.100      0.922      -0.436       0.397
# ==============================================================================
# Omnibus:                        4.515   Durbin-Watson:                   1.516
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                1.646
# Skew:                          -0.236   Prob(JB):                        0.439
# Kurtosis:                       1.713   Cond. No.                         8.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# anxiety
X2 = sm.add_constant(data_part2_scaled)
est = sm.OLS(anxiety_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                 -0.106
# Method:                 Least Squares   F-statistic:                    0.7597
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.643
# Time:                        18:41:40   Log-Likelihood:                -5.1694
# No. Observations:                  21   AIC:                             28.34
# Df Residuals:                      12   BIC:                             37.74
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0931      0.089     23.426      0.000       1.898       2.288
# x1             0.1246      0.211      0.590      0.566      -0.336       0.585
# x2            -0.2078      0.176     -1.184      0.259      -0.590       0.175
# x3             0.3139      0.237      1.322      0.211      -0.204       0.831
# x4             0.0953      0.269      0.354      0.729      -0.490       0.681
# x5            -0.1418      0.139     -1.023      0.327      -0.444       0.160
# x6             0.1525      0.145      1.055      0.312      -0.163       0.468
# x7            -0.2394      0.204     -1.172      0.264      -0.685       0.206
# x8             0.1098      0.204      0.537      0.601      -0.335       0.555
# ==============================================================================
# Omnibus:                        0.295   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.863   Jarque-Bera (JB):                0.391
# Skew:                           0.237   Prob(JB):                        0.822
# Kurtosis:                       2.527   Cond. No.                         8.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# anxiety
X2 = sm.add_constant(data_part2_scaled)
est = sm.OLS(tone_np, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.9442
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):              0.517
# Time:                        18:41:43   Log-Likelihood:               -0.11631
# No. Observations:                  21   AIC:                             18.23
# Df Residuals:                      12   BIC:                             27.63
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1956      0.070     31.259      0.000       2.043       2.349
# x1            -0.1878      0.166     -1.131      0.280      -0.550       0.174
# x2            -0.2535      0.138     -1.837      0.091      -0.554       0.047
# x3             0.3889      0.187      2.083      0.059      -0.018       0.796
# x4             0.4557      0.211      2.156      0.052      -0.005       0.916
# x5            -0.0277      0.109     -0.254      0.804      -0.265       0.210
# x6            -0.0256      0.114     -0.226      0.825      -0.273       0.222
# x7            -0.2748      0.161     -1.711      0.113      -0.625       0.075
# x8            -0.0640      0.161     -0.398      0.697      -0.414       0.286
# ==============================================================================
# Omnibus:                        1.973   Durbin-Watson:                   1.754
# Prob(Omnibus):                  0.373   Jarque-Bera (JB):                0.587
# Skew:                           0.002   Prob(JB):                        0.746
# Kurtosis:                       3.819   Cond. No.                         8.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
